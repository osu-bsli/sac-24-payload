# %% [markdown]
# Import the libraries we need:

# %%
import numpy as np
import cv2, PIL
from cv2 import aruco
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

from aruco.aruco_utils import ARUCO_DICT, aruco_display

# %%
IMG_FILE_PATH='images/aruco1.png'
ARUCO_TYPE='DICT_6X6_250'

# %%
print("Loading image...")
image = cv2.imread(IMG_FILE_PATH)
h,w,_ = image.shape
width=600
height = int(width*(h/w))
image = cv2.resize(image, (width, height), interpolation=cv2.INTER_CUBIC)
# Out:
# Loading image...

# %%
def display_im(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
print("Detecting tags....")
arucoDict = cv2.aruco.getPredefinedDictionary(ARUCO_DICT[ARUCO_TYPE])
arucoParams = cv2.aruco.DetectorParameters()

ar_detector = cv2.aruco.ArucoDetector(arucoDict, arucoParams)

corners, ids, rejected = ar_detector.detectMarkers(image)

detected_markers = aruco_display(corners, ids, rejected, image)
display_im(image)
# Out:
# Detecting tags....
# [Inference] ArUco marker ID: 2
